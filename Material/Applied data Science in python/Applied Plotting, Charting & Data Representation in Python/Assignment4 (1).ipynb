# %%
# Import useful libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.gridspec as gridspec

# %matplotlib notebook

# %%
data = pd.read_csv('Loan payments data.csv')
data = data[['Gender', 'loan_status', 'age', 'education', 'Principal']]
data
# Out:
#      Gender         loan_status  age             education  Principal
# 0      male             PAIDOFF   45  High School or Below       1000
# 1    female             PAIDOFF   50              Bechalor       1000
# 2    female             PAIDOFF   33              Bechalor       1000
# 3      male             PAIDOFF   27               college       1000
# 4    female             PAIDOFF   28               college       1000
# 5      male             PAIDOFF   35       Master or Above        300
# 6      male             PAIDOFF   29               college       1000
# 7      male             PAIDOFF   36               college       1000
# 8      male             PAIDOFF   28               college       1000
# 9      male             PAIDOFF   26               college        800
# 10     male             PAIDOFF   29               college        300
# 11     male             PAIDOFF   39  High School or Below       1000
# 12     male             PAIDOFF   26               college       1000
# 13   female             PAIDOFF   26               college        900
# 14     male             PAIDOFF   27  High School or Below       1000
# 15     male             PAIDOFF   26               college        800
# 16     male             PAIDOFF   40  High School or Below       1000
# 17     male             PAIDOFF   32  High School or Below       1000
# 18     male             PAIDOFF   32  High School or Below       1000
# 19     male             PAIDOFF   26               college        800
# 20     male             PAIDOFF   26               college       1000
# 21   female             PAIDOFF   43  High School or Below       1000
# 22     male             PAIDOFF   25  High School or Below       1000
# 23     male             PAIDOFF   26               college       1000
# 24     male             PAIDOFF   26               college       1000
# 25     male             PAIDOFF   29  High School or Below       1000
# 26     male             PAIDOFF   39              Bechalor        800
# 27     male             PAIDOFF   34              Bechalor       1000
# 28     male             PAIDOFF   31               college       1000
# 29     male             PAIDOFF   33               college       1000
# ..      ...                 ...  ...                   ...        ...
# 470    male  COLLECTION_PAIDOFF   32  High School or Below       1000
# 471    male  COLLECTION_PAIDOFF   27              Bechalor       1000
# 472    male  COLLECTION_PAIDOFF   33               college        800
# 473    male  COLLECTION_PAIDOFF   30  High School or Below       1000
# 474  female  COLLECTION_PAIDOFF   26  High School or Below        800
# 475  female  COLLECTION_PAIDOFF   35               college       1000
# 476  female  COLLECTION_PAIDOFF   46               college        800
# 477    male  COLLECTION_PAIDOFF   27               college       1000
# 478    male  COLLECTION_PAIDOFF   22  High School or Below       1000
# 479    male  COLLECTION_PAIDOFF   27              Bechalor       1000
# 480    male  COLLECTION_PAIDOFF   30              Bechalor       1000
# 481    male  COLLECTION_PAIDOFF   27  High School or Below       1000
# 482    male  COLLECTION_PAIDOFF   47               college        800
# 483    male  COLLECTION_PAIDOFF   30               college       1000
# 484    male  COLLECTION_PAIDOFF   26               college       1000
# 485    male  COLLECTION_PAIDOFF   38  High School or Below       1000
# 486    male  COLLECTION_PAIDOFF   46  High School or Below        800
# 487    male  COLLECTION_PAIDOFF   35              Bechalor       1000
# 488    male  COLLECTION_PAIDOFF   45               college       1000
# 489    male  COLLECTION_PAIDOFF   36               college       1000
# 490    male  COLLECTION_PAIDOFF   38  High School or Below       1000
# 491    male  COLLECTION_PAIDOFF   27               college       1000
# 492    male  COLLECTION_PAIDOFF   27              Bechalor       1000
# 493    male  COLLECTION_PAIDOFF   29               college       1000
# 494    male  COLLECTION_PAIDOFF   30  High School or Below       1000
# 495    male  COLLECTION_PAIDOFF   28  High School or Below       1000
# 496    male  COLLECTION_PAIDOFF   26  High School or Below       1000
# 497    male  COLLECTION_PAIDOFF   30               college        800
# 498  female  COLLECTION_PAIDOFF   38               college       1000
# 499    male  COLLECTION_PAIDOFF   28  High School or Below       1000
#
# [500 rows x 5 columns]

# %%
plt.style.use('fivethirtyeight')
plt.figure()
plt.subplot(121)
sns.barplot(x=data[data['loan_status'] == 'PAIDOFF'].groupby('education')['Gender'].count().index,
           y=data[data['loan_status'] == 'PAIDOFF'].groupby('education')['Gender'].count().values)
plt.xticks(rotation=15)

plt.subplot(233)
sns.kdeplot(data['age'])
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Age Kde Plot System Analysis')

plt.subplot(236)
sns.countplot(data['Gender'],hue=data['education'])
# Out:
# <img src="data:image/png;base64,..." width="640">
